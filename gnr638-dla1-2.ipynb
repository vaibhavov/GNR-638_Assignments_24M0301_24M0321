tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential56.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential52.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential62.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential47.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential70.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential64.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential79.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential51.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential45.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential46.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential19.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential24.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential42.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential43.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential55.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential01.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential76.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential67.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential50.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential81.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential34.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential97.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/denseresidential/denseresidential03.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot92.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot87.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot97.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot57.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot03.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot67.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot09.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot30.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot52.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot75.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot00.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot02.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot43.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot19.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot08.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot05.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot29.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot66.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot89.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot49.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot25.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot65.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot23.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot99.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot94.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot13.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot55.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot18.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot85.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot12.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot36.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot88.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot20.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot16.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot91.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot46.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot39.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot62.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot71.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot01.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot07.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot77.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot48.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot74.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot10.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot26.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot61.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot35.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot33.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot81.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot73.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot56.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot69.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot22.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot63.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot58.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot21.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot70.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot76.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot15.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot96.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot59.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot68.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot11.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot93.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot24.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot41.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot82.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot38.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot27.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot80.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot37.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot90.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot06.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot40.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot31.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot54.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot98.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot78.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot44.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot64.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot86.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot42.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot17.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot50.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot34.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot51.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot95.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot32.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot45.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot60.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot47.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot14.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot28.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot83.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot53.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot72.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot04.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot79.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/parkinglot/parkinglot84.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks73.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks83.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks50.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks60.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks66.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks67.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks72.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks18.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks61.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks97.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks78.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks14.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks74.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/storagetanks/storagetanks46.tif
# ...
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse10.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse85.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse77.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse06.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse12.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse61.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse86.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse18.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse26.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse82.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse31.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse83.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse76.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse13.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse58.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse07.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse69.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse03.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse90.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse71.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse64.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse70.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse42.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse57.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse99.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse48.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse34.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse91.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse04.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse53.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse01.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse16.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse38.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse30.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse89.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse02.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse72.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse21.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse00.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse47.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse59.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse15.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse68.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse88.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse78.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse20.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse73.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse55.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse28.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse95.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse39.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse75.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse33.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse97.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse45.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse27.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse32.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse62.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse24.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse67.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse11.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse84.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse66.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse93.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse74.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse17.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/golfcourse/golfcourse52.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural14.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural27.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural34.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural86.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural45.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural57.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural58.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural18.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural53.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural25.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural49.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural77.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural64.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural12.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural65.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural21.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural36.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural35.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural15.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural81.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural11.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural60.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural75.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural24.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural29.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural38.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural48.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural71.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural10.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural43.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural54.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural56.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural01.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural41.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural37.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural30.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural40.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural82.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural89.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural04.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural32.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural07.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural88.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural97.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural06.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural50.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural99.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural68.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural73.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural19.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural55.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural61.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural46.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural87.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural59.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural44.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural33.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural93.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural79.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural96.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural72.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural22.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural84.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural70.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural20.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural13.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural98.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural52.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural69.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural05.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural39.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural62.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural91.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural74.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural83.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural78.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural67.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural00.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural28.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural42.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural03.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural08.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural90.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural66.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural80.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural31.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural26.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural76.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural02.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural23.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural95.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural09.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural51.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural92.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural85.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural16.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural94.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural47.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural63.tif
# /kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images/agricultural/agricultural17.tif

# %%
import os
import cv2
import numpy as np
import pickle
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
def get_image_paths_and_labels(data_path):
    """Get paths and labels for all images in the directory."""
    print("Step 1: Gathering image paths and labels...")
    image_paths = []
    labels = []
    categories = os.listdir(data_path)
    for category in categories:
        category_path = os.path.join(data_path, category)
        if os.path.isdir(category_path):
            for img_name in os.listdir(category_path):
                img_path = os.path.join(category_path, img_name)
                image_paths.append(img_path)
                labels.append(category)
    print(f"Found {len(image_paths)} images across {len(categories)} categories.")
    return image_paths, labels, categories

# %%
def extract_bag_of_sifts(image_paths, labels, vocab_size=100):
    """Extract Bag of SIFT features from each image, ensuring labels remain in sync."""
    sift = cv2.SIFT_create()
    descriptors_list = []
    valid_image_paths = []
    valid_labels = []

    print("Step 2.1: Detecting and computing SIFT descriptors for images...")
    for img_path, label in zip(image_paths, labels):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Unable to read image {img_path}. Skipping...")
            continue
        kp, des = sift.detectAndCompute(img, None)
        if des is not None:
            descriptors_list.append(des)
            valid_image_paths.append(img_path)
            valid_labels.append(label)

    print("Step 2.2: Clustering SIFT descriptors to create visual vocabulary...")
    descriptors = np.vstack(descriptors_list)
    _, labels, centers = cv2.kmeans(
        descriptors.astype(np.float32),
        vocab_size,
        None,
        (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2),
        10,
        cv2.KMEANS_RANDOM_CENTERS
    )
    vocab = centers
    print(f"Visual vocabulary created with {vocab_size} clusters.")

    print("Step 2.3: Creating Bag-of-Words histograms for each image...")
    histograms = []
    for des in descriptors_list:
        histogram = np.zeros(vocab_size)
        for descriptor in des:
            distances = np.linalg.norm(vocab - descriptor, axis=1)
            cluster_id = np.argmin(distances)
            if cluster_id < vocab_size:
                histogram[cluster_id] += 1
        histograms.append(histogram)

    print("Bag-of-Words histograms created.")
    return np.array(histograms), valid_labels, vocab

# %%
def train_and_evaluate_classifiers(features_train, labels_train, features_test, labels_test, classifier_type='nearest_neighbor'):
    """Train and evaluate classifiers."""
    print(f"Step 3: Training and evaluating {classifier_type} classifier...")
    le = LabelEncoder()
    encoded_labels_train = le.fit_transform(labels_train)
    encoded_labels_test = le.transform(labels_test)

    if classifier_type == 'nearest_neighbor':
        classifier = KNeighborsClassifier(n_neighbors=3)
    elif classifier_type == 'support_vector_machine':
        classifier = SVC(kernel='linear')
    else:
        raise ValueError(f"Unknown classifier type: {classifier_type}")

    classifier.fit(features_train, encoded_labels_train)
    predicted_labels = classifier.predict(features_test)
    predicted_labels = le.inverse_transform(predicted_labels)

    accuracy_report = classification_report(labels_test, predicted_labels)
    print(f"Accuracy report for {classifier_type}:")
    print(accuracy_report)

    return predicted_labels, classifier, accuracy_report

# %%
def visualize_tsne(features, labels, categories, output_path='tsne_visualization.png'):
    """Visualize the distribution of image features using T-SNE."""
    print("Step 4: Visualizing feature distribution using T-SNE...")
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(features)

    plt.figure(figsize=(10, 8))
    for i, category in enumerate(categories):
        category_indices = [j for j, label in enumerate(labels) if label == category]
        plt.scatter(tsne_results[category_indices, 0], tsne_results[category_indices, 1], label=category)

    plt.legend()
    plt.title('T-SNE Visualization of Image Features')
    plt.savefig(output_path)
    print(f"T-SNE visualization saved as {output_path}.")

# %%
def plot_confusion_matrix(cm, categories, output_path='confusion_matrix.png', title='Confusion Matrix', cmap=plt.cm.Blues):
    """Plot the confusion matrix."""
    print("Step 5: Plotting confusion matrix...")
    plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(categories))
    plt.xticks(tick_marks, categories, rotation=45)
    plt.yticks(tick_marks, categories)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(output_path)
    print(f"Confusion matrix saved as {output_path}.")

# %%
def main(data_path):
    print("Starting the image classification process...\n")

    # Step 1: Get paths and labels for images
    image_paths, labels, categories = get_image_paths_and_labels(data_path)

    # Step 2: Iterate through different vocabulary sizes
    vocab_sizes = [50, 100, 150, 200, 250]
    accuracies = []
    
    for vocab_size in vocab_sizes:
        print(f"\nProcessing with vocabulary size: {vocab_size}")
        
        # Step 2: Extract features with current vocab size
        features, valid_labels, vocab = extract_bag_of_sifts(image_paths, labels, vocab_size=vocab_size)

        # Step 3: Split data into train and test sets (70-30)
        features_train, features_test, labels_train, labels_test = train_test_split(features, valid_labels, test_size=0.3, random_state=42)

        # Step 4: Train and evaluate classifiers
        nn_predictions, nn_classifier, nn_accuracy_report = train_and_evaluate_classifiers(features_train, labels_train, features_test, labels_test, 'nearest_neighbor')
        svm_predictions, svm_classifier, svm_accuracy_report = train_and_evaluate_classifiers(features_train, labels_train, features_test, labels_test, 'support_vector_machine')

        # Step 5: Compute confusion matrices
        nn_cm = confusion_matrix(labels_test, nn_predictions, labels=categories)
        svm_cm = confusion_matrix(labels_test, svm_predictions, labels=categories)

        # Step 6: Save confusion matrix plots
        plot_confusion_matrix(nn_cm, categories, output_path=f'nn_confusion_matrix_{vocab_size}.png', title=f'Nearest Neighbor Confusion Matrix ({vocab_size})')
        plot_confusion_matrix(svm_cm, categories, output_path=f'svm_confusion_matrix_{vocab_size}.png', title=f'SVM Confusion Matrix ({vocab_size})')

        # Step 7: Save t-SNE visualizations
        visualize_tsne(features, valid_labels, categories, output_path=f'tsne_visualization_{vocab_size}.png')

        # Store accuracy for plotting later
        accuracies.append({
            'vocab_size': vocab_size,
            'nn_accuracy': nn_accuracy_report,
            'svm_accuracy': svm_accuracy_report
        })

    # Step 8: Plot accuracy vs vocab size
    vocab_sizes = np.array(vocab_sizes)
    nn_accuracies = [float(acc['nn_accuracy'].split()[-2]) for acc in accuracies]
    svm_accuracies = [float(acc['svm_accuracy'].split()[-2]) for acc in accuracies]

    plt.figure(figsize=(8, 6))
    plt.plot(vocab_sizes, nn_accuracies, label='Nearest Neighbor')
    plt.plot(vocab_sizes, svm_accuracies, label='SVM')
    plt.xlabel('Vocabulary Size')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy vs Vocabulary Size')
    plt.legend()
    plt.savefig('accuracy_vs_vocab_size.png')
    print("Accuracy vs Vocabulary Size plot saved.")

    print("\nImage classification process completed.")

# Example usage
main('/kaggle/input/uc-merced-land-use-dataset/UCMerced_LandUse/Images')
